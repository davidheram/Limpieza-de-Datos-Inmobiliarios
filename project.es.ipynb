# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
ds["price"].idxmax()
price = ds.loc[13110]["price"]
direccion = ds.loc[13110]["address"]
street = ds.loc[13110]["realEstate_name"]

print("la casa con direccion en ", direccion, street, "tiene un precio de ",  price, " usd")
# Out:
# la casa con direccion en  El Escorial engel volkers torrelodones tiene un precio de  8500000  usd

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
ds["price"].idxmin()
price1 = ds.loc[366]["price"].min()
address1 = ds.loc[366]["address"]
street1 = ds.loc[366]["realEstate_name"]

print("la casa con direccion en ", address1, street1, "tiene un precio de ", price1, "usd")
# Out:
# la casa con direccion en  Parla esalje tiene un precio de  0 usd

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
idG = ds["surface"].idxmax()

idCh = ds["surface"].idxmin()
casaGrande = ds.loc[id,["surface", "address","realEstate_name"]]
casaChica = ds.loc[idCh,["surface", "address","realEstate_name"]]

print(casaGrande)
print(casaChica)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 135917102579536 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 4
#       1 idG = ds["surface"].idxmax()
#       3 idCh = ds["surface"].idxmin()
# ----> 4 casaGrande = ds.loc[id,["surface", "address","realEstate_name"]]
#       5 casaChica = ds.loc[idCh,["surface", "address","realEstate_name"]]
#       7 print(casaGrande)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
# ...

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
', '.join(ds["level5"].unique())
# Out:
# 'Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bu
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
#     Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
def nan_o_no(ds,col):
    if ds[col].isnull().sum()==0:
        return False
    else: 
        return True 
    
for col in ds.columns:
    print(col, ds[col].isnull().sum(), nan_o_no(ds,col))
# Out:
# Unnamed: 0 0 False
# id_realEstates 0 False
# isNew 0 False
# realEstate_name 10 True
# phone_realEstate 794 True
# url_inmueble 0 False
# rooms 353 True
# bathrooms 345 True
# surface 1250 True
# price 0 False
# date 0 False
# description 142 True
# address 0 False
# country 0 False
# level1 0 False
# level2 0 False
# level3 0 False
# level4 6643 True
# level5 0 False
# level6 14627 True
# level7 2277 True
# level8 8579 True
# upperLevel 0 False
# countryId 0 False
# level1Id 0 False
# level2Id 0 False
# level3Id 0 False
# level4Id 0 False
# level5Id 0 False
# level6Id 0 False
# level7Id 0 False
# level8Id 0 False
# accuracy 0 False
# latitude 0 False
# longitude 0 False
# zipCode 15335 True
# customZone 15335 True

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
ds_antes = ds.shape

filas_sinNAs = ds.dropna(axis=0)

total_sinNas = filas_sinNAs.dropna(axis=1)

ds_despues = total_sinNas.shape

print(ds_antes)
print(ds_despues)
# Out:
# (15335, 37)
# (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)

# %%
ds[ds['level5'] =="Arroyomolinos (Madrid)"]["price"].mean()
# Out:
# np.float64(294541.59854014596)

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

ds[ds['level5'] =="Arroyomolinos (Madrid)"]['price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# En la grafica se aprecia que el rango promedio para la mayoria de esa poblacion oscila entre los 200,000 y 400,000.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
valdemorillo = ds[ds["level5"] == "Valdemorillo"]["price"].mean()
galapagar = ds[ds["level5"] == "Galapagar"]["price"].mean()

print("precio promedio en Valdemorillo:", valdemorillo)
print("precio promedio Galapagar:", galapagar)

print("los precios promedio de esas poblaciones no son iguales, pero su diferencia es minima")
# Out:
# precio promedio en Valdemorillo: 363860.2931034483
# precio promedio Galapagar: 360063.20238095237
# los precios promedio de esas poblaciones no son iguales, pero su diferencia es minima

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ds["pps"] = ds["price"] / ds["surface"]

m2_valdemorillo = ds[ds["address"] == "Valdemorillo"]["pps"].mean()

m2_galapagar = ds[ds["address"] == "Galapagar"]["pps"].mean()

print("precio por m2 en Valdemorillo:", m2_valdemorillo)
print("precio por m2 en Galapagar", m2_galapagar)
# Out:
# precio por m2 en Valdemorillo: 1322.0148553932524
# precio por m2 en Galapagar 1518.5182736000133

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(np.log(ds['price']),
            np.log(ds['surface']))
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# en los registros de dispersion se aprecia que entre los registros están incrementando hacia el eje X y Y se mantiene bajo.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
agencias = ds["realEstate_name"].unique()

agencias1 = ds["realEstate_name"].nunique()

print("el data set tiene", agencias1, agencias)


for agencia in agencias:
    print("-", agencia)
# Out:
# el data set tiene 1821 ['ferrari 57 inmobiliaria' 'tecnocasa fuenlabrada ferrocarril'
#  'look find boadilla' ... 'redpiso villaverde bajo san cristobal'
#  'gestion comercial' 'nieves']
# - ferrari 57 inmobiliaria
# - tecnocasa fuenlabrada ferrocarril
# - look find boadilla
# - expimad
# - modesta
# - inmobiliaria nuevo leganes
# - gm house
# - alia consulting inmobiliario sl
# - tecnocasa navalcarnero
# - mejocasa
# - fisol
# - oih
# - mario
# - matibo
# - isabel
# - isidro paris molano
# - ruben
# - david perez
# - myriam curiel
# - jorge
# - particular
# - engels volkers sanchinarro
# - jaime valcarce consulting inmobiliario
# - inmobiliaria reylank propiedades
# - altter
# - spi real estate
# - nozar sa
# - vivienda2
# - vivantial
# - ingescasa
# - nurin
# - egido real estate
# - zona madrid
# - fincas fernandez
# - cr homes
# - century 21 antilla
# - esalje
# - sinergical inmobiliaria
# - donpiso pozuelo
# - housfy real estate aicat 7922
# - viviendas365com
# ...

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
poblacion = ds["level5"].value_counts()

num = poblacion.idxmax()

poblacion1= poblacion.max()

print("la poblacion con mayor numer de casas es:", num,"y tiene un numere de", poblacion1, "casas")
# Out:
# la poblacion con mayor numer de casas es:  Madrid Capital y tiene un numere de 6643 casas

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
ds1 = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

ds1
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
import matplotlib.pyplot as plt

import seaborn as sns 

sns.barplot(data = ds1, x= "level5", y= "price", estimator= "median", color = "blue")
# Out:
# <Axes: xlabel='level5', ylabel='price'>

# %% [markdown]
# El grafico muestra que Getafe, respecto su mediana, es la poblacion con precios mas altos que las demas.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
sub = ds1[['rooms', 'bathrooms', 'surface','price']]

for col in sub.columns:
    media = round(sub[col].mean(),2)
    varianza = round(sub[col].var(ddof=1),2)

    print(f"{col}: media = {media}, varianza {varianza}")
# Out:
# rooms: media = 3.02, varianza 0.72
# bathrooms: media = 1.63, varianza 0.57
# surface: media = 111.75, varianza 4263.05
# price: media = 223094.48, varianza 14921367508.05

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
poblacion = ds1.groupby("level5")["price"].idxmax()

casa = ds.loc[poblacion, ["address","price"]]

casa
# Out:
#                                      address    price
# 5585                                Alcorcón   950000
# 11561  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881                                  Getafe  1050000
# 10412           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

ds1["price_norm"] = ds1.groupby("level5")["price"].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
# Out:
# /tmp/ipykernel_613/947082678.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds1["price_norm"] = ds1.groupby("level5")["price"].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
plt.figure(figsize=(8, 5))

for poblacion in ds1["level5"].unique():
    subset = ds1[ds1["level5"] == poblacion]
    
    plt.hist(subset["price_norm"], bins=15, alpha=0.5, label=poblacion)

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
ds1["pps"] = ds1["price"] / ds1["surface"]

Getafe = ds1[ds1["address"] == "Getafe"]["pps"].mean()

Alcorcon = ds1[ds1["address"] == "Alcorcón"]["pps"].mean()

print(Getafe)

print(Alcorcon)

print( "el precio promedio entre las 2 poblaciones no es igual, pero son muy similares.")
# Out:
# 1921.8334775699416
# 2171.0596744534632
# el precio promedio entre las 2 poblaciones no es igual, pero son muy similares.
# /tmp/ipykernel_613/436087220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds1["pps"] = ds1["price"] / ds1["surface"]

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
poblaciones = ds1["level5"].unique()
fig, axes = plt.subplots(2, 2, figsize =(10,8))
axes = axes.flatten()

for i, poblacion in enumerate(poblaciones):
    subset = ds1[ds1["level5"] == poblacion]
    axes[i].scatter(subset["surface"], subset["price"], alpha=0.6, edgecolor="k")

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
